# %%
x=5
y=5
for i in range(x):
  for j in range(i):
    print("*",end="")
  print(" ")

for a in range(x,0):
  for b in range(a):
    print("*", end="")
  print(" ")
# Out:
#
# *
# **
# ***
# ****

# %%
x=5
for i in range(0,5):
  for j in range(1,i-1):
    print("-")
  print(i)
# Out:
# 0
# 1
# 2
# -
# 3
# -
# -
# 4
